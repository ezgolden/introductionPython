# %% [markdown]
# # M�dulo 0: Introdu��o ao Python e Programa��o
#
# ## 1. Fundamentos da Programa��o com Python
# - Vari�veis, Tipos de Dados e Opera��es B�sicas
# - Estruturas de Controle (if, for, while)
# - Fun��es e Estruturas de Dados (listas, dicion�rios, conjuntos)
#
# ## 2. Ferramentas para An�lise de Dados
# - Python no Google Colab
# - Instala��o e Importa��o de Bibliotecas
#
# ## 3. Bibliotecas para Extra��o de Dados
# - Web scraping com BeautifulSoup e Scrapy
# - Leitura de PDFs com PyPDF2
# - Convers�o de �udio para texto com SpeechRecognition
#
# ## Exemplo de C�digo
# ```python
# # Exemplo de leitura de PDF com PyPDF2
# from PyPDF2 import PdfReader
#
# with open("exemplo.pdf", "rb") as file:
#     reader = PdfReader(file)
#     for page in reader.pages:
#         print(page.extract_text())
# ```
#
# ## Exerc�cios
# 1. Escreva um script para ler um arquivo PDF e extrair seu conte�do.
# 2. Utilize a biblioteca SpeechRecognition para converter um arquivo de �udio para texto.
# 3. Realize uma raspagem simples de dados de um site com BeautifulSoup.

# %% [markdown]
# #Exc 1 : Leitura de arquivos

# %% [markdown]
# ---

# %%
# !pip install PyPDF2
# Out:
# ...
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py", line 447, in run
#     conflicts = self._determine_conflicts(to_install)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py", line 578, in _determine_conflicts
#     return check_install_conflicts(to_install)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/operations/check.py", line 101, in check_install_conflicts
# ...

# %%
from PyPDF2 import PdfReader
#importando bibliotecas do PyPDF

caminho_arquivo = "/content/R20250516.pdf"

# %%
with open(caminho_arquivo, "rb") as file:
    reader = PdfReader(file)
    for page in reader.pages:
        print(page.extract_text())
# Out:
# Expectativas de Mercado 16 de maio de 2025
# FocusRelatório de Mercado
# Mediana - Agregado Há 4
# semanasHá 1
# semanaHojeComp.
# semanal *Resp.
# **5 dias
# úteisResp.
# ***Há 4
# semanasHá 1
# semanaHojeComp.
# semanal *Resp.
# **5 dias
# úteisResp.
# ***Há 4
# semanasHá 1
# semanaHojeComp.
# semanal *Resp.
# **Há 4
# semanasHá 1
# semanaHojeComp.
# semanal *Resp.
# **
# IPCA (variação %) 5,57 5,51 5,50▼ (5) 149 5,47 63 4,50 4,50 4,50 (1) 144 4,50 62 4,00 4,00 4,00 (13) 119 3,80 3,80 3,80 (2) 107
# PIB Total (variação % sobre ano anterior) 2,00 2,00 2,02▲ (1) 113 2,00 36 1,70 1,70 1,70 (4) 108 1,70 35 2,00 2,00 2,00 (7) 80 2,00 2,00 2,00 (62) 79
# Câmbio (R$/US$) 5,90 5,85 5,82▼ (3) 120 5,81 48 5,96 5,90 5,90 (1) 118 5,90 47 5,89 5,80 5,80 (1) 89 5,85 5,82 5,85▲ (1) 84
# Selic (% a.a) 15,00 14,75 14,75 (2) 143 14,75 73 12,50 12,50 12,50 (16) 137 12,25 72 10,50 10,50 10,50 (14) 112 10,00 10,00 10,00 (21) 103
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Exc 1: Audio + criação de função

# %%
# !pip install SpeechRecognition
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 24.4 MB/s eta 0:00:00
# ...

# %%
# Ensure this cell is executed before the next one that uses sr
import speech_recognition as sr

caminho_audio = "/content/audio_convertido.wav"

# %%
def ouvir_microfone():
    # Todo o código dentro da função deve ser indentado (geralmente com 4 espaços)
    r = sr.Recognizer()
    with sr.AudioFile(caminho_audio) as source:
        audio = r.record(source)
        texto = r.recognize_google(audio, language="pt-BR")
        print(texto)

# %% [markdown]
# exemplo de como fazer uma função com o codigo de ouvir audio, agora em baixo um exemplo de como declarar essa função no código:

# %%
ouvir_microfone()
# Out:
# Oi eu sou um robô

# %% [markdown]
# -----------------------------------------------------------

# %% [markdown]
# #Exc 1: Dados em site

# %%
# !pip install beautifulsoup4
# !pip install requests

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

url = "https://pt.wikipedia.org/wiki/Lista_das_maiores_empresas_do_Brasil"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
tables = soup.find_all('table',{'class', 'wikitable'})

df = pd.read_html(str(tables))[0]
df.head()
# Out:
# <ipython-input-24-6b7b4d5e87a8>:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(tables))[0]
#    #  Forbes Global 2000             Nome  Receita (em bilhões de US$)  \
# 0  1                  58        Petrobras                        12417
# 1  2                  98    Itaú Unibanco                         5317
# 2  3                 139             Vale                         4143
# 3  4                 171  Banco do Brasil                         5398
# 4  5                 173         Bradesco                         5626
#
#    Lucro (em bilhões de US$)  Ativos (em bilhões de US$)  \
# 0                       3647                        1849
# 1                        575                        4414
# 2                       1598                        8772
# 3                        576                       38027
# ...

# %% [markdown]
# #Exc 2: localização de dados com **API**

# %% [markdown]
# #documentação
# Acessando o webservice de CEP
# Para acessar o webservice, um CEP no formato de {8} dígitos deve ser fornecido, exemplo: "01001000".
# Após o CEP, deve ser fornecido o tipo de retorno desejado, que deve ser "json" ou "xml".
#
# Exemplo de consulta de CEP:
# viacep.com.br/ws/01001000/json/
#
# Validação do CEP
# Quando consultado um CEP de formato inválido, exemplo: "950100100" (9 dígitos), "95010A10" (alfanumérico), "95010 10" (espaço), o código de retorno da consulta será um 400 (Bad Request). Antes de acessar o webservice, valide o formato do CEP e certifique-se que o mesmo possua {8} dígitos. Exemplo de como validar o formato do CEP em javascript está disponível nos exemplos abaixo.
#
# Quando consultado um CEP de formato válido, porém inexistente, por exemplo: "99999999", o retorno conterá um valor de "erro" igual a "true". Isso significa que o CEP consultado não foi encontrado na base de dados. Veja como tratar este "erro" em javascript nos exemplos abaixo.

# %%
import requests

# %%
cep ="88338455"

url = f"https://viacep.com.br/ws/{cep}/json/"
respostas = requests.get(url)

dados = respostas.json()
print(dados)
# Out:
# {'cep': '88338-455', 'logradouro': 'Rua Pardal', 'complemento': '', 'unidade': '', 'bairro': 'Ariribá', 'localidade': 'Balneário Camboriú', 'uf': 'SC', 'estado': 'Santa Catarina', 'regiao': 'Sul', 'ibge': '4202008', 'gia': '', 'ddd': '47', 'siafi': '8039'}

# %%
print(dados['bairro'])

print(type(dados))
bairro = dados['bairro']
print(type(bairro))
# Out:
# Ariribá
# <class 'dict'>
# <class 'str'>
